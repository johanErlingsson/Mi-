# %%
import folium
import os
import base64

# Function to convert image to base64
def image_to_base64(image_path):
    with open(image_path, 'rb') as image_file:
        encoded_string = base64.b64encode(image_file.read()).decode()
    return encoded_string

# Create a map centered at a specific location
m = folium.Map(location=[61.6452025, -6.9812540], zoom_start=12)

# Define the path to the images
image_path_1 = 'C:/Users/jerli/Pictures/Camera Roll/WIN_20240603_14_09_14_Pro.jpg'
image_path_2 = 'C:/Users/jerli/Pictures/Camera Roll/WIN_20240603_14_09_14_Pro.jpg'
image_path_3 = 'C:/Users/jerli/Pictures/Camera Roll/WIN_20240603_14_09_14_Pro.jpg'

# Convert images to base64
img1_base64 = image_to_base64(image_path_1)
img2_base64 = image_to_base64(image_path_2)
img3_base64 = image_to_base64(image_path_3)

# Add markers with image popups
folium.Marker(
    [61.6452025, -6.9812540],
    popup=folium.Popup(f'<b>Nípubakkin</b><br><img src="data:image/jpeg;base64,{img1_base64}" width="150" height="150">', max_width=300)
).add_to(m)

folium.Marker(
    [61.7702787, -6.8553095],
    popup=folium.Popup(f'<b>Knútur</b><br><img src="data:image/jpeg;base64,{img2_base64}" width="150" height="150">', max_width=300)
).add_to(m)

folium.Marker(
    [61.7049463, -6.76496603],
    popup=folium.Popup(f'<b>múlun St</b><br><img src="data:image/jpeg;base64,{img3_base64}" width="150" height="150">', max_width=300)
).add_to(m)

# Define the path and filename
save_path = 'C:/Users/jerli/Desktop/New folder/map_with_photos.html'

# Create directory if it doesn't exist
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# Save map to the specified HTML file
m.save(save_path)

# %%
import folium
import os
import base64

# Function to convert image to base64
def image_to_base64(image_path):
    with open(image_path, 'rb') as image_file:
        encoded_string = base64.b64encode(image_file.read()).decode()
    return encoded_string

# Create a map centered at a specific location
m = folium.Map(location=[61.6452025, -6.9812540], zoom_start=12)

# Define the path to the images
image_path_1 = 'C:/Users/jerli/Pictures/Camera Roll/WIN_20240603_14_09_14_Pro.jpg'
image_path_2 = 'C:/Users/jerli/Pictures/Camera Roll/WIN_20240603_14_09_14_Pro.jpg'
image_path_3 = 'C:/Users/jerli/Pictures/Camera Roll/WIN_20240603_14_09_14_Pro.jpg'

# Convert images to base64
img1_base64 = image_to_base64(image_path_1)
img2_base64 = image_to_base64(image_path_2)
img3_base64 = image_to_base64(image_path_3)

# Add markers with image popups
folium.Marker(
    [61.6452025, -6.9812540],
    popup=folium.Popup(f'<b>Nípubakkin</b><br><img src="data:image/jpeg;base64,{img1_base64}" width="150" height="150">', max_width=150)
).add_to(m)

folium.Marker(
    [61.7702787, -6.8553095],
    popup=folium.Popup(f'<b>Knútur</b><br><img src="data:image/jpeg;base64,{img2_base64}" width="150" height="150">', max_width=300)
).add_to(m)

folium.Marker(
    [61.7049463, -6.76496603],
    popup=folium.Popup(f'<b>múlun St</b><br><img src="data:image/jpeg;base64,{img3_base64}" width="150" height="150">', max_width=300)
).add_to(m)

# Define coordinates for the lines
coords1 = [[61.6452025, -6.9812540], [61.7702787, -6.8553095]]
coords2 = [[61.7702787, -6.8553095], [61.7049463, -6.76496603]]
coords3 = [[61.7049463, -6.76496603], [61.6452025, -6.9812540]]

# Add lines with different styles
folium.PolyLine(coords1, color='blue', weight=2.5, opacity=1).add_to(m)  # Solid blue line
folium.PolyLine(coords2, color='red', weight=2.5, opacity=1, dash_array='5,10').add_to(m)  # Dotted red line
folium.PolyLine(coords3, color='green', weight=2.5, opacity=1, dash_array='10,20').add_to(m)  # Dotted green line

# Define the path and filename
save_path = 'C:/Users/jerli/Desktop/New folder/map_with_photos_and_lines.html'

# Create directory if it doesn't exist
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# Save map to the specified HTML file
m.save(save_path)

# %%
import folium
import os
import base64

# Function to convert image to base64
def image_to_base64(image_path):
    with open(image_path, 'rb') as image_file:
        encoded_string = base64.b64encode(image_file.read()).decode()
    return encoded_string

# Create a map centered at a specific location
m = folium.Map(location=[61.6452025, -6.9812540], zoom_start=12)

# Define the path to the images
image_path_22_1 = 'C:/Users/jerli/Desktop/New folder/22_1.JPG'
image_path_22_2 = 'C:/Users/jerli/Desktop/New folder/22_2.JPG'
image_path_22_3 = 'C:/Users/jerli/Desktop/New folder/22_3.JPG'

# Convert images to base64
img1_base64 = image_to_base64(image_path_22_1)
img2_base64 = image_to_base64(image_path_22_2)
img3_base64 = image_to_base64(image_path_22_3)

# HTML content for the popup with images side by side and full-screen view on click
popup_22 = f"""
<b>22</b><br>
<a href="data:image/jpeg;base64,{img1_base64}" target="_blank"><img src="data:image/jpeg;base64,{img1_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img2_base64}" target="_blank"><img src="data:image/jpeg;base64,{img2_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img3_base64}" target="_blank"><img src="data:image/jpeg;base64,{img3_base64}" width="150" height="150"></a>
"""

# Add markers with image popups
folium.Marker(
    [61.62783333, -6.85733333],
    popup=folium.Popup(popup_22, max_width=320)
).add_to(m)

# Define the path and filename
save_path = 'C:/Users/jerli/Desktop/New folder/mid_V1.html'

# Create directory if it doesn't exist
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# Save map to the specified HTML file
m.save(save_path)

# %%
import folium
import os
import base64

# Function to convert image to base64
def image_to_base64(image_path):
    with open(image_path, 'rb') as image_file:
        encoded_string = base64.b64encode(image_file.read()).decode()
    return encoded_string

# Create a map centered at a specific location
m = folium.Map(location=[61.6452025, -6.9812540], zoom_start=12)

# Define custom icons
icon_url = 'C:/Users/jerli/Desktop/New folder/icons8-position-64.png'  
icon_size = (30, 30)  # Adjust the size of the icon here

# Define the path to the images
image_path_22_1 = 'C:/Users/jerli/Desktop/New folder/22_1.JPG'
image_path_22_2 = 'C:/Users/jerli/Desktop/New folder/22_2.JPG'
image_path_22_3 = 'C:/Users/jerli/Desktop/New folder/22_3.JPG'
#23
image_path_23_1 = 'C:/Users/jerli/Desktop/New folder/23_1.JPG'
image_path_23_2 = 'C:/Users/jerli/Desktop/New folder/23_2.JPG'
#25
image_path_25_1 = 'C:/Users/jerli/Desktop/New folder/25_1.JPG'
image_path_25_2 = 'C:/Users/jerli/Desktop/New folder/25_2.JPG'
#26
image_path_26_1 = 'C:/Users/jerli/Desktop/New folder/26_1.JPG'
image_path_26_2 = 'C:/Users/jerli/Desktop/New folder/26_2.JPG'
#27
image_path_27_1 = 'C:/Users/jerli/Desktop/New folder/27_1.JPG'
image_path_27_2 = 'C:/Users/jerli/Desktop/New folder/27_2.JPG'
#28
image_path_28_1 = 'C:/Users/jerli/Desktop/New folder/28_1.JPG'
image_path_28_2 = 'C:/Users/jerli/Desktop/New folder/28_2.JPG'
#29
image_path_29_x = 'C:/Users/jerli/Desktop/New folder/29_x.JPG'
#36
image_path_36_1 = 'C:/Users/jerli/Desktop/New folder/36_1.JPG'
image_path_36_2 = 'C:/Users/jerli/Desktop/New folder/36_2.JPG'
#37
image_path_37_1 = 'C:/Users/jerli/Desktop/New folder/37_1.JPG'
image_path_37_2 = 'C:/Users/jerli/Desktop/New folder/37_2.JPG'

# Convert images to base64
img1_base64 = image_to_base64(image_path_22_1)
img2_base64 = image_to_base64(image_path_22_2)
img3_base64 = image_to_base64(image_path_22_3)
img4_base64 = image_to_base64(image_path_23_1)
img5_base64 = image_to_base64(image_path_23_2)
img6_base64 = image_to_base64(image_path_25_1)
img7_base64 = image_to_base64(image_path_25_2)
img8_base64 = image_to_base64(image_path_26_1)
img9_base64 = image_to_base64(image_path_26_2)

img271_base64 = image_to_base64(image_path_27_1)
img272_base64 = image_to_base64(image_path_27_2)
img281_base64 = image_to_base64(image_path_28_1)
img282_base64 = image_to_base64(image_path_28_2)
img29x_base64 = image_to_base64(image_path_29_x)
img361_base64 = image_to_base64(image_path_36_1)
img362_base64 = image_to_base64(image_path_36_2)
img371_base64 = image_to_base64(image_path_37_1)
img372_base64 = image_to_base64(image_path_37_2)



# HTML content for the popup with images side by side and Lightbox2 for fullscreen view
#22
popup_22 = f"""
<b>22 (61° 37,67N - 6° 51,44V) d.25m</b><br>
<a href="data:image/jpeg;base64,{img1_base64}" data-lightbox="image-22" data-title="Image 1"><img src="data:image/jpeg;base64,{img1_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img2_base64}" data-lightbox="image-22" data-title="Image 2"><img src="data:image/jpeg;base64,{img2_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img3_base64}" data-lightbox="image-22" data-title="Image 3"><img src="data:image/jpeg;base64,{img3_base64}" width="150" height="150"></a>
<p>Fjallarøðin vestan Snjóstøðugarðin suður undan Múlunum, og Glyvrabergsnæsi norður undan Mjóanesið.</p>
"""
#23
popup_23 = f"""
<b>23 (61° 37,65N - 6° 51,54V) d.26m</b><br>
<a href="data:image/jpeg;base64,{img4_base64}" data-lightbox="image-22" data-title="Image 1"><img src="data:image/jpeg;base64,{img4_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img5_base64}" data-lightbox="image-22" data-title="Image 2"><img src="data:image/jpeg;base64,{img5_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<p>Fjallsrøðin vestan Snóstoðugarðin suður undan Múlunum, og Rituskorð norður undan Mjóanesið.<p>
"""
#25
popup_25 = f"""
<b>25 (61° 37,30N - 6° 52,40V) d.24m</b><br>
<a href="data:image/jpeg;base64,{img6_base64}" data-lightbox="image-22" data-title="Image 1"><img src="data:image/jpeg;base64,{img6_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img7_base64}" data-lightbox="image-22" data-title="Image 2"><img src="data:image/jpeg;base64,{img7_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<p>Flesin í Sandvík eystur undan Mjóanesið, og Vaðanskarð suður undan Múlunum.<p>
"""
#26
popup_26 = f"""
<b>26 (61° 36,97N - 6° 52,00V) d.25m</b><br>
<a href="data:image/jpeg;base64,{img8_base64}" data-lightbox="image-22" data-title="Image 1"><img src="data:image/jpeg;base64,{img8_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img9_base64}" data-lightbox="image-22" data-title="Image 2"><img src="data:image/jpeg;base64,{img9_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<p>Flesin í Sandvík eystur undan Mjóanesið, og Jókin suður undan Giljabrekkuni.(kalvamið) <p>
"""
#27
popup_27 = f"""
<b>27 (61° 36,31N - 6° 51,30V) d.26m</b><br>
<a href="data:image/jpeg;base64,{img271_base64}" data-lightbox="image-22" data-title="Image 1"><img src="data:image/jpeg;base64,{img271_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img272_base64}" data-lightbox="image-22" data-title="Image 2"><img src="data:image/jpeg;base64,{img272_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<p>Flesin í Sandvík undan Mjóanesið, og Vatnsdalsfossur undan Snæbjarnaryggi. (sildafiskur um summari) <p>
"""
#28
popup_28 = f"""
<b>28 (61° 36,46N - 6° 50,64V) d.21m</b><br>
<a href="data:image/jpeg;base64,{img281_base64}" data-lightbox="image-22" data-title="Image 1"><img src="data:image/jpeg;base64,{img281_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img282_base64}" data-lightbox="image-22" data-title="Image 2"><img src="data:image/jpeg;base64,{img282_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<p>Vatnsdalsfossur undan Snæbjarnaryggi, og skortur sunnast í Syðriskorð í ryggin á uruni undir Nevinum.<p>
"""
#29
popup_29 = f"""
<b>29 (61° 36,82N - 6° 52,59V) d.19m</b><br>
<a href="data:image/jpeg;base64,{img29x_base64}" data-lightbox="image-22" data-title="Image 1"><img src="data:image/jpeg;base64,{img29x_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<p>Borgin og Líratúgva yvir eitt. <br>(Tað sjálvsama við hesum miðið er at tað hevur bert eitt ýti) <p>
"""
#36
popup_36 = f"""
<b>36 (61° 37,02N - 6° 52,84V)</b><br>
<a href="data:image/jpeg;base64,{img361_base64}" data-lightbox="image-22" data-title="Image 1"><img src="data:image/jpeg;base64,{img361_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img362_base64}" data-lightbox="image-22" data-title="Image 2"><img src="data:image/jpeg;base64,{img362_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<p>Ribbingarmúlið undan Nevinum, og Knútur á Skúoy undan Mjóanesið.<p>
"""
#37
popup_37 = f"""
<b>37 (61° 36N - 6° 55V) d.10m</b><br>
<a href="data:image/jpeg;base64,{img371_base64}" data-lightbox="image-22" data-title="Image 1"><img src="data:image/jpeg;base64,{img371_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<a href="data:image/jpeg;base64,{img372_base64}" data-lightbox="image-22" data-title="Image 2"><img src="data:image/jpeg;base64,{img372_base64}" width="150" height="150" style="margin-right: 5px;"></a>
<p>Lýsjakrógv undan rygginum undir Lýsjamúla, og Kletturin í erva á stóri Dímun suður undan Mjóanesið.<p>
"""
# Add markers with image popups
#22
folium.Marker(
    [61.62783333, -6.85733333],
    popup=folium.Popup(popup_22, max_width=320),
    icon=folium.CustomIcon(icon_url, icon_size=icon_size)
).add_to(m)

#23
folium.Marker(
    [61.6275, -6.859],
    popup=folium.Popup(popup_23, max_width=320),
    icon=folium.CustomIcon(icon_url, icon_size=icon_size)
).add_to(m)
#25
folium.Marker(
    [61.62166666, -6.87333333],
    popup=folium.Popup(popup_25, max_width=320),
    icon=folium.CustomIcon(icon_url, icon_size=icon_size)
).add_to(m)
#26
folium.Marker(
    [61.61616666, -6.86666666],
    popup=folium.Popup(popup_26, max_width=320),
    icon=folium.CustomIcon(icon_url, icon_size=icon_size)
).add_to(m)
#27
folium.Marker(
    [61.60516666, -6.855],
    popup=folium.Popup(popup_27, max_width=320),
    icon=folium.CustomIcon(icon_url, icon_size=icon_size)
).add_to(m)
#28
folium.Marker(
    [61.60766666, -6.844],
    popup=folium.Popup(popup_28, max_width=320),
    icon=folium.CustomIcon(icon_url, icon_size=icon_size)
).add_to(m)
#29
folium.Marker(
    [61.61366666, -6.8765],
    popup=folium.Popup(popup_29, max_width=200),
    icon=folium.CustomIcon(icon_url, icon_size=icon_size)
).add_to(m)
#29
folium.Marker(
    [61.61366666, -6.8765],
    popup=folium.Popup(popup_29, max_width=200),
    icon=folium.CustomIcon(icon_url, icon_size=icon_size)
).add_to(m)
#36
folium.Marker(
    [61.617, -6.88066666],
    popup=folium.Popup(popup_36, max_width=320),
    icon=folium.CustomIcon(icon_url, icon_size=icon_size)
).add_to(m)
#37
folium.Marker(
    [61.6, -6.91666666],
    popup=folium.Popup(popup_37, max_width=320),
    icon=folium.CustomIcon(icon_url, icon_size=icon_size)
).add_to(m)

# Define the path and filename
save_path = 'C:/Users/jerli/Desktop/New folder/mid_V1.html'

# Create directory if it doesn't exist
os.makedirs(os.path.dirname(save_path), exist_ok=True)

# Save map to the specified HTML file
m.save(save_path)

# Append Lightbox2 script and CSS to the saved HTML
lightbox_css = '<link href="https://cdnjs.cloudflare.com/ajax/libs/lightbox2/2.11.3/css/lightbox.min.css" rel="stylesheet">'
lightbox_js = '<script src="https://cdnjs.cloudflare.com/ajax/libs/lightbox2/2.11.3/js/lightbox.min.js"></script>'

with open(save_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Insert Lightbox2 CSS and JS before the closing </head> and </body> tags
html_content = html_content.replace('</head>', f'{lightbox_css}</head>')
html_content = html_content.replace('</body>', f'{lightbox_js}</body>')

with open(save_path, 'w', encoding='utf-8') as file:
    file.write(html_content)
